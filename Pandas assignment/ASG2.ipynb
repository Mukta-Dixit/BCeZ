# %% [markdown]
# ### Question 2
# In this question, you will be implementing simple data analysis programs on the provided
# dataset. You will learn how to subset a DataFrame, how to make simple changes to a DataFrame,
# and how to visualize the results of your analysis. Also, you will be practicing the usage of if and
# for statements in your data analysis process. Make a new copy of the gapminder DataFrame and
# do the following:

# %% [markdown]
# ### 2.1 Subsetting a DataFrame

# %% [markdown]
# ### a) Subset all the rows related to New Zealand and print the results.

# %%
import numpy as np
import pandas as pd

# %%
asg=pd.read_csv("gapminder.tsv",delimiter="\t")

# %%
asg_df=pd.DataFrame(asg)
asg_df
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
k=asg_df[asg_df.country=="New Zealand"]
k
# Out:
#           country continent  year  lifeExp      pop    gdpPercap
# 1092  New Zealand   Oceania  1952   69.390  1994794  10556.57566
# 1093  New Zealand   Oceania  1957   70.260  2229407  12247.39532
# 1094  New Zealand   Oceania  1962   71.240  2488550  13175.67800
# 1095  New Zealand   Oceania  1967   71.520  2728150  14463.91893
# 1096  New Zealand   Oceania  1972   71.890  2929100  16046.03728
# 1097  New Zealand   Oceania  1977   72.220  3164900  16233.71770
# 1098  New Zealand   Oceania  1982   73.840  3210650  17632.41040
# 1099  New Zealand   Oceania  1987   74.320  3317166  19007.19129
# 1100  New Zealand   Oceania  1992   76.330  3437674  18363.32494
# 1101  New Zealand   Oceania  1997   77.550  3676187  21050.41377
# 1102  New Zealand   Oceania  2002   79.110  3908037  23189.80135
# 1103  New Zealand   Oceania  2007   80.204  4115771  25185.00911

# %%
(69.390+1994794+10556.57566)/3
# Out:
# 668473.3218866667

# %%
k.rename(columns={'pop':'population'}, inplace=True)
k
# Out:
# C:\Users\Dixit\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#           country continent  year  lifeExp  population    gdpPercap
# 1092  New Zealand   Oceania  1952   69.390     1994794  10556.57566
# 1093  New Zealand   Oceania  1957   70.260     2229407  12247.39532
# 1094  New Zealand   Oceania  1962   71.240     2488550  13175.67800
# 1095  New Zealand   Oceania  1967   71.520     2728150  14463.91893
# 1096  New Zealand   Oceania  1972   71.890     2929100  16046.03728
# 1097  New Zealand   Oceania  1977   72.220     3164900  16233.71770
# 1098  New Zealand   Oceania  1982   73.840     3210650  17632.41040
# 1099  New Zealand   Oceania  1987   74.320     3317166  19007.19129
# ...

# %% [markdown]
# ### (b) Extract the 'lifeExp' column from what you have subset in (a).

# %%
k1=k.loc[1092:1103,['lifeExp']]
k1
# Out:
#       lifeExp
# 1092   69.390
# 1093   70.260
# 1094   71.240
# 1095   71.520
# 1096   71.890
# 1097   72.220
# 1098   73.840
# 1099   74.320
# 1100   76.330
# 1101   77.550
# 1102   79.110
# 1103   80.204

# %% [markdown]
# ### (c) Extract the information from the 'continent' and 'population' columns in 1982 from what you have subset in a

# %%
k2=k.loc[1092:1103,['continent','population']]
k2
# Out:
#      continent  population
# 1092   Oceania     1994794
# 1093   Oceania     2229407
# 1094   Oceania     2488550
# 1095   Oceania     2728150
# 1096   Oceania     2929100
# 1097   Oceania     3164900
# 1098   Oceania     3210650
# 1099   Oceania     3317166
# 1100   Oceania     3437674
# 1101   Oceania     3676187
# 1102   Oceania     3908037
# 1103   Oceania     4115771

# %%
k3=k[["continent","population"]][k.year==1982]
k3
# Out:
#      continent  population
# 1098   Oceania     3210650

# %% [markdown]
# ### 2.2 Data Analysis and Visualization

# %% [markdown]
# ### (a) Calculate the average of the columns 'lifeExp', 'population', and 'gdpPercap' through the years for New Zealand and print them.

# %%
k4=k[["lifeExp","population","gdpPercap"]].mean(axis=1)
k4
# Out:
# 1092    6.684733e+05
# 1093    7.472416e+05
# 1094    8.339323e+05
# 1095    9.142285e+05
# 1096    9.817393e+05
# 1097    1.060402e+06
# 1098    1.076119e+06
# 1099    1.112083e+06
# 1100    1.152038e+06
# 1101    1.232438e+06
# 1102    1.310435e+06
# 1103    1.380345e+06
# dtype: float64

# %% [markdown]
# ### (b) Draw one figure with three sub-plots to show the three columns 'lifeExp', 'population', and 'gdpPercap' over the span of the years provided in the column 'year'. Use 'lifeExp', 'population', and 'gdpPercap' as y axis information in each subplot, and 'year' as x axis in all the subplots. Label the axes properly and put a title for each plot. Set the x axis numbers to be the exact years provided in the column 'year'.Draw figure on subset of all rows related to New Zealand.

# %%
 import matplotlib as plot
k5=k.plot(y=["lifeExp","population","gdpPercap"],x="year",subplots=True,kind="bar",figsize=(10,10))
k5
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000005A28208>,
# ...
#       dtype=object)

# %% [markdown]
# ### (c) Write a piece of code that compares the average lifeExp between New Zealand and Japan, then prints the bigger average lifeExp and the continent where the country with higher average lifeExp is located.

# %%
k6=k["lifeExp"].mean()
k6#mean of new zealand
# Out:
# 73.98949999999999

# %%
kj=asg_df[asg_df.country=="Japan"]
kj
# Out:
#     country continent  year  lifeExp        pop     gdpPercap
# 792   Japan      Asia  1952   63.030   86459025   3216.956347
# 793   Japan      Asia  1957   65.500   91563009   4317.694365
# 794   Japan      Asia  1962   68.730   95831757   6576.649461
# 795   Japan      Asia  1967   71.430  100825279   9847.788607
# 796   Japan      Asia  1972   73.420  107188273  14778.786360
# 797   Japan      Asia  1977   75.380  113872473  16610.377010
# 798   Japan      Asia  1982   77.110  118454974  19384.105710
# 799   Japan      Asia  1987   78.670  122091325  22375.941890
# 800   Japan      Asia  1992   79.360  124329269  26824.895110
# 801   Japan      Asia  1997   80.690  125956499  28816.584990
# 802   Japan      Asia  2002   82.000  127065841  28604.591900
# 803   Japan      Asia  2007   82.603  127467972  31656.068060

# %%
k7=kj["lifeExp"].mean()
k7#mean of japan
# Out:
# 74.82691666666668

# %%
if(k6>k7):
    print(k[["continent","country"]])
else:
    print(kj[["continent","country"]])
# Out:
#     continent country
# 792      Asia   Japan
# 793      Asia   Japan
# 794      Asia   Japan
# 795      Asia   Japan
# 796      Asia   Japan
# 797      Asia   Japan
# 798      Asia   Japan
# 799      Asia   Japan
# 800      Asia   Japan
# 801      Asia   Japan
# 802      Asia   Japan
# 803      Asia   Japan

# %% [markdown]
# ### 2.3 Adding Columns to a DataFrame .

# %% [markdown]
# ### Write a program that subsets all the information related to New Zealand, adds an extra column at the right side of it named 'devFac' abbreviated for developing factor which is calculated using:
#
# ### DevFac = ((0.7 * lifeExpnorm) + (0.3 * gdpPercapnorm))/popnorm
#
# ### where lifeExpnorm, gdpPercapnorm, and popnorm are the normalized values according to:
# ### lifeExpnorm = lifeExp/lifeExpmax
# ### gdpPercapnorm = gdpPercap/gdpPercapmax
# ### popnorm = population/populationmax
#
# ### where lifeExpmax, gdpPercapmax, and populationmax are the maximum values of lifeExp, gdpPercap, and population respectively for New Zealand during the provided years. Finally save the new created DataFrame as a csv file.

# %%
k
# Out:
#           country continent  year  lifeExp  population    gdpPercap
# 1092  New Zealand   Oceania  1952   69.390     1994794  10556.57566
# 1093  New Zealand   Oceania  1957   70.260     2229407  12247.39532
# 1094  New Zealand   Oceania  1962   71.240     2488550  13175.67800
# 1095  New Zealand   Oceania  1967   71.520     2728150  14463.91893
# 1096  New Zealand   Oceania  1972   71.890     2929100  16046.03728
# 1097  New Zealand   Oceania  1977   72.220     3164900  16233.71770
# 1098  New Zealand   Oceania  1982   73.840     3210650  17632.41040
# 1099  New Zealand   Oceania  1987   74.320     3317166  19007.19129
# 1100  New Zealand   Oceania  1992   76.330     3437674  18363.32494
# 1101  New Zealand   Oceania  1997   77.550     3676187  21050.41377
# 1102  New Zealand   Oceania  2002   79.110     3908037  23189.80135
# 1103  New Zealand   Oceania  2007   80.204     4115771  25185.00911

# %%
populationmax=k["population"].max()
populationmax
# Out:
# 4115771

# %%
popnorm = k["population"]/populationmax
popnorm
# Out:
# 1092    0.484671
# 1093    0.541674
# 1094    0.604638
# 1095    0.662853
# 1096    0.711677
# 1097    0.768969
# 1098    0.780085
# 1099    0.805965
# 1100    0.835244
# 1101    0.893195
# 1102    0.949527
# 1103    1.000000
# Name: population, dtype: float64

# %%
gdpPercapmax=k["gdpPercap"].max()

# %%
gdpPercapnorm=k["gdpPercap"]/gdpPercapmax
gdpPercapnorm
# Out:
# 1092    0.419161
# 1093    0.486297
# 1094    0.523156
# 1095    0.574307
# 1096    0.637127
# 1097    0.644579
# 1098    0.700115
# 1099    0.754703
# 1100    0.729137
# 1101    0.835831
# 1102    0.920778
# 1103    1.000000
# Name: gdpPercap, dtype: float64

# %%
lifeExpmax=k["lifeExp"].max()

# %%
lifeExpnorm = k["lifeExp"]/lifeExpmax
lifeExpnorm
# Out:
# 1092    0.865169
# 1093    0.876016
# 1094    0.888235
# 1095    0.891726
# 1096    0.896339
# 1097    0.900454
# 1098    0.920652
# 1099    0.926637
# 1100    0.951698
# 1101    0.966909
# 1102    0.986360
# 1103    1.000000
# Name: lifeExp, dtype: float64

# %%
DevFac = ((0.7 * lifeExpnorm) + (0.3 * gdpPercapnorm))/popnorm
DevFac
# Out:
# 1092    1.508996
# 1093    1.401397
# 1094    1.287897
# 1095    1.201625
# 1096    1.150206
# 1097    1.071163
# 1098    1.095383
# 1099    1.085726
# 1100    1.059486
# 1101    1.038503
# 1102    1.018070
# 1103    1.000000
# dtype: float64

# %%
k["DevFac"]=DevFac
k
# Out:
# C:\Users\Dixit\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#           country continent  year  lifeExp  population    gdpPercap    DevFac
# 1092  New Zealand   Oceania  1952   69.390     1994794  10556.57566  1.508996
# 1093  New Zealand   Oceania  1957   70.260     2229407  12247.39532  1.401397
# 1094  New Zealand   Oceania  1962   71.240     2488550  13175.67800  1.287897
# 1095  New Zealand   Oceania  1967   71.520     2728150  14463.91893  1.201625
# 1096  New Zealand   Oceania  1972   71.890     2929100  16046.03728  1.150206
# 1097  New Zealand   Oceania  1977   72.220     3164900  16233.71770  1.071163
# ...
